# %% [markdown]
# # Global Indecies Data Ingestion & EDA

# %% [markdown]
# ## Setup Environment

# %%
#Package Imports

import os
import requests
import pandas as pd
from dotenv import load_dotenv
import pathlib
import alpaca_trade_api as tradeapi
import json
import investpy

# %matplotlib inline

# %%
#Load .env environment variable
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Data Ingestion

# %%
investpy.indices.get_index_countries()
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'ivory coast',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'luxembourg',
#  'malawi',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestinian territory',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
#  'russia',
#  'rwanda',
#  'saudi arabia',
#  'serbia',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'sweden',
#  'switzerland',
#  'taiwan',
#  'tanzania',
#  'thailand',
#  'tunisia',
#  'turkey',
#  'uganda',
#  'ukraine',
#  'dubai',
#  'united kingdom',
#  'united states',
#  'venezuela',
#  'vietnam',
#  'zambia',
#  'zimbabwe']

# %%
global_indices = investpy.indices.get_indices(country= None)

lookup = "KOSDAQ"

global_indices[global_indices['full_name'].str.contains(lookup)]
# Out:
#           country                                 name  \
# 3902  south korea                              KQ Grow
# 3909  south korea                               KQ 150
# 3912  south korea                           KQ Venture
# 3913  south korea                          KQ Standard
# 3914  south korea                             KQ Small
# 3915  south korea                             KQ Prime
# 3916  south korea                           KQ Mid 300
# 3921  south korea                     KQ Metal Product
# 3923  south korea               KQ Nonmetallic Product
# 3924  south korea                 KQ IT S/W & Services
# 3925  south korea                            KQ IT H/W
# 3926  south korea                            KOSDAQ IT
# 3927  south korea                  KQ Digital Contents
# 3935  south korea                               KQ 100
# 3936  south korea                               KOSDAQ
# 3937  south korea               KQ Other Manufacturing
# 3938  south korea                    KQ Other Services
# 3939  south korea               KQ Paper Wood Products
# 3940  south korea             KQ Publishing & Printing
# 3941  south korea  KQ Telecom & Broadcasting Equipment
# 3950  south korea                      KQ Distribution
# 3951  south korea                      KQ Construction
# 3952  south korea                 KQ Computer Services
# 3953  south korea                 KQ Computer Hardware
# 4003                     KOSDAQ IT Components     KQ48      KRW
# 4004                          KOSDAQ Internet     KQ40      KRW
# 4005               KOSDAQ Vehicles Components     KQ32      KRW
#
#                    class         market
# 3902       other_indices  world_indices
# 3909       other_indices  world_indices
# 3912       other_indices  world_indices
# 3913       other_indices  world_indices
# 3914       other_indices  world_indices
# 3915       other_indices  world_indices
# 3916       other_indices  world_indices
# 3921       other_indices  world_indices
# 3923       other_indices  world_indices
# 3924       other_indices  world_indices
# 3925       other_indices  world_indices
# 3926       other_indices  world_indices
# 3927       other_indices  world_indices
# 3935  additional_indices  world_indices
# 3936  additional_indices  world_indices
# 3937       other_indices  world_indices
# 3938       other_indices  world_indices
# 3939       other_indices  world_indices
# 3940       other_indices  world_indices
# 3941       other_indices  world_indices
# 3950     primary_sectors  world_indices
# 3951     primary_sectors  world_indices
# 3952     primary_sectors  world_indices
# 3953     primary_sectors  world_indices
# 3954     primary_sectors  world_indices
# 3956     primary_sectors  world_indices
# 3975     primary_sectors  world_indices
# 3976     primary_sectors  world_indices
# 3977     primary_sectors  world_indices
# 3978     primary_sectors  world_indices
# 3993     primary_sectors  world_indices
# 3994     primary_sectors  world_indices
# 3995     primary_sectors  world_indices
# 3996     primary_sectors  world_indices
# 3997     primary_sectors  world_indices
# 3998     primary_sectors  world_indices
# 3999     primary_sectors  world_indices
# 4000     primary_sectors  world_indices
# 4001     primary_sectors  world_indices
# 4002     primary_sectors  world_indices
# 4003     primary_sectors  world_indices
# 4004     primary_sectors  world_indices
# 4005     primary_sectors  world_indices

# %%
index_list = [5272, 7273, 7282, 6445, 7716, 2357, 4774, 5274, 5275, 5648, 834, 611, 3162, 3090, 3104, 3749, 2270, 2356, 2196, 4747, 4813, 4734, 2088, 2095, 2100, 2599, 2600, 2836, 2848, 410, 576, 560, 580, 3958, 3936] 

top_indices = global_indices[global_indices.index.isin(index_list)]
top_indices.head()
# Out:
#     country                name                  full_name    symbol currency  \
# 410  brazil             Bovespa                    Bovespa      BVSP      BRL
# 560  canada             S&P/TSX          S&P/TSX Composite    GSPTSE      CAD
# 576  canada          S&P/TSX 60                 S&P/TSX 60     SPTSE      CAD
# 580  canada     S&P/TSX Venture  S&P/TSX Venture Composite    SPCDNX      CAD
# 611   china  CSI 300 Net TR USD         CSI 300 Net TR USD  CSIID301      USD
#
#                   class          market
# 410       major_indices   world_indices
# 560       major_indices   world_indices
# 576  additional_indices   world_indices
# 580  additional_indices   world_indices
# 611       other_indices  global_indices

# %%
df = investpy.indices.get_index_historical_data(
    index = 'Dow 30',
    country = 'united states',
    from_date = '01/01/2000',
    to_date = '01/01/2021'    
)

df.head()
# Out:
#                 Open      High       Low     Close  Volume Currency
# Date
# 2007-01-04  12467.32  12510.26  12405.47  12480.69       0      USD
# 2007-01-05  12480.05  12504.40  12326.79  12398.01       0      USD
# 2007-01-08  12393.93  12445.37  12337.53  12423.49       0      USD
# 2007-01-09  12424.77  12516.66  12337.85  12416.60       0      USD
# 2007-01-10  12417.00  12487.18  12313.01  12442.16       0      USD
