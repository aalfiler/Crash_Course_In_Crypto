# %%
# Initial imports
import panel as pn
pn.extension('plotly')

import datetime as dt
import hvplot.pandas
import json
import math
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import requests
import seaborn as sns
import time

from pathlib import Path
from dotenv import load_dotenv

# %matplotlib inline

# %% [markdown]
# ## Part 1: Volume of Trading Activity by Fiat Currency
#
# Coinbase provides historical data for 3 fiat currencies: the US Dollar (USD), the Euro (EUR), and the British Pound (GBP). The following visualizations compare the volumes of trading activity between those fiat currencies from 2012 to 2021.

# %%
fiat_currencies = ["USD", "EUR", "GBP"]

# Load Coinbase historical data from CSV file
coinbase_historical_data_filepath = Path("../data/coinbase_historical_data.csv")
trading_volume_data_df = pd.read_csv(coinbase_historical_data_filepath)
trading_volume_data_df["date"] = pd.to_datetime(trading_volume_data_df["date"])
trading_volume_data_df.head()
# Out:
#       low    high    open   close     volume base_currency quote_currency  \
# 0  0.4563  0.4783  0.4572  0.4699   212031.0          ALGO            EUR
# 1  0.4128  0.4705  0.4191  0.4575  2312202.0          ALGO            EUR
# 2  0.3528  0.4438  0.3804  0.4188  2636644.0          ALGO            EUR
# 3  0.3691  0.4533  0.4526  0.3793  1693635.0          ALGO            EUR
# 4  0.4010  0.4530  0.4317  0.4525  3203612.0          ALGO            EUR
#
#         date
# 0 2021-01-24
# 1 2021-01-23
# 2 2021-01-22
# 3 2021-01-21
# 4 2021-01-20

# %%
def trading_volume():
    """
    Visualize trading volume for each fiat currency.
    """
    fiat_volume_df = trading_volume_data_df[["date", "quote_currency", "volume"]].groupby(["date", "quote_currency"]).sum()
    return fiat_volume_df.hvplot.line(x="date", y="volume", by="quote_currency", xlabel="Date", ylabel="Volume", title="Daily Volume of Trading Activity by Fiat Currency", height=500, width=1000)

# %%
def unique_cryptocurrency_count():
    """
    Visualize the number of unique traded cryptocurrencies for each fiat currency.
    """
    crypto_count_df = trading_volume_data_df.groupby(["date", "quote_currency"])["base_currency"].nunique()
    return crypto_count_df.hvplot.line(x="date", y="base_currency", by="quote_currency", xlabel="Date", ylabel="Count", title="Daily Count of Unique Cryptocurrencies Traded", height=300, width=1000)

# %%
def trading_volume_std():
    """
    Visualize trading volume standard deviation for each fiat currency.
    """
    # Get daily change in trading volume
    fiat_volume_data_df = pd.concat([trading_volume_data_df[trading_volume_data_df["quote_currency"] == fiat].groupby(["date"])["volume"].sum() for fiat in fiat_currencies], axis=1)
    fiat_volume_data_df.columns = fiat_currencies
    fiat_volume_pct_df = fiat_volume_data_df.pct_change()

    # Calculate rolling standard deviation
    rolling_volume_std = fiat_volume_pct_df.rolling(window=21).std()

    # Plot rolling standard deviation
    return px.line(data_frame=rolling_volume_std, width=1000, height=400, 
        labels={
            "date": "Date",
            "value": "Standard Deviation"
        },
        title="Standard Deviation of Volume Trading Activity (21-day rolling window)")

# %%
# Get the top 3 cryptocurrency by trading volume for each fiat currency
for fiat in fiat_currencies:
    top3 = list(trading_volume_data_df[trading_volume_data_df["quote_currency"] == fiat].groupby(["base_currency"])["volume"].sum().sort_values(ascending=False).head(3).index)
    print(f"{fiat} Top 3 by Trading Volume: {top3}")
# Out:
# USD Top 3 by Trading Volume: ['XLM', 'GRT', 'OXT']
# EUR Top 3 by Trading Volume: ['XLM', 'GRT', 'ZRX']
# GBP Top 3 by Trading Volume: ['GRT', 'NU', 'ALGO']

# %%
# visualize trend of top 10 by volume cryptocurrencies
top10_usd_cryptos = list(trading_volume_data_df[trading_volume_data_df["quote_currency"] == "USD"].groupby(["base_currency"])["volume"].sum().sort_values(ascending=False).head(10).index)
cb_usd_volume_df = trading_volume_data_df[(trading_volume_data_df["quote_currency"] == "USD") & (trading_volume_data_df["base_currency"].isin(top10_usd_cryptos)) & (trading_volume_data_df["date"].dt.year >= 2019)].groupby(["date", "base_currency"])["volume"].sum()
cb_usd_volume_df.hvplot.line(x="date", y="volume", by="base_currency", xlabel="Date", ylabel="Volume", title="USD: Trend of Top 10 by Volume Cryptocurrencies", height=500, width=1000)
# Out:
# :NdOverlay   [base_currency]
#    :Curve   [date]   (volume)

# %% [markdown]
# # Part 2: Compare Between Cryptos
#
# Analyze the closing prices (Jan 2011 - Jan 2021) for the top 10 trading cryptos per CoinMarketCap

# %%
all_crypto = pd.ExcelFile('../data/CoinMarketCap_18JAN2020-close.xlsx')
all_close = pd.read_excel(all_crypto, 'All')
all_close.head()
# Out:
#         Date  Bitcoin-BTC  Ethereum-ETH  Bitcoin-BSV  Litecoin-LTC  \
# 0 2020-12-31     29374.15        730.37       163.12        126.23
# 1 2020-12-30     29001.72        737.80       163.63        124.69
# 2 2020-12-29     28840.95        751.62       166.90        129.47
# 3 2020-12-28     27362.44        731.52       164.40        129.04
# 4 2020-12-27     27084.81        730.40       168.49        130.05
#
#    Monero-XMR  Dash-DASH  Kusama-KSM  Zcash-ZEC  Bitcoin Cash-BCH  Counos-CCXX
# 0      136.05      88.24       71.96      63.99            343.05        89.10
# 1      156.57      99.61       62.04      64.20            358.81        87.88
# 2      159.37     101.68       61.26      66.54            353.09        87.67
# 3      161.39     104.04       58.24      69.02            362.09        87.39
# 4      166.49     107.27       50.32      67.65            338.18        87.18

# %%
all_close.shape
# Out:
# (2805, 11)

# %%
all_close.dtypes
# Out:
# Date                datetime64[ns]
# Bitcoin-BTC                float64
# Ethereum-ETH               float64
# Bitcoin-BSV                float64
# Litecoin-LTC               float64
# Monero-XMR                 float64
# Dash-DASH                  float64
# Kusama-KSM                 float64
# Zcash-ZEC                  float64
# Bitcoin Cash-BCH           float64
# Counos-CCXX                float64
# dtype: object

# %%
all_close.isnull().sum()
# Out:
# Date                   0
# Bitcoin-BTC            0
# Ethereum-ETH         831
# Bitcoin-BSV         2021
# Litecoin-LTC           0
# Monero-XMR           389
# Dash-DASH            292
# Kusama-KSM          2420
# Zcash-ZEC           1281
# Bitcoin Cash-BCH    1548
# Counos-CCXX         2550
# dtype: int64

# %%
all_close["Bitcoin-BTC"] = all_close["Bitcoin-BTC"].fillna(0)
all_close["Ethereum-ETH"] = all_close["Ethereum-ETH"].fillna(0)
all_close["Bitcoin-BSV"] = all_close["Bitcoin-BSV"].fillna(0)
all_close["Litecoin-LTC"] = all_close["Litecoin-LTC"].fillna(0)
all_close["Monero-XMR"] = all_close["Monero-XMR"].fillna(0)
all_close["Dash-DASH"] = all_close["Dash-DASH"].fillna(0)
all_close["Kusama-KSM"] = all_close["Kusama-KSM"].fillna(0)
all_close["Zcash-ZEC"] = all_close["Zcash-ZEC"].fillna(0)
all_close["Bitcoin Cash-BCH"] = all_close["Bitcoin Cash-BCH"].fillna(0)
all_close["Counos-CCXX"] = all_close["Counos-CCXX"].fillna(0)

# %%
all_close.isnull().sum()
# Out:
# Date                0
# Bitcoin-BTC         0
# Ethereum-ETH        0
# Bitcoin-BSV         0
# Litecoin-LTC        0
# Monero-XMR          0
# Dash-DASH           0
# Kusama-KSM          0
# Zcash-ZEC           0
# Bitcoin Cash-BCH    0
# Counos-CCXX         0
# dtype: int64

# %%
all_date_index = all_close.set_index("Date")
all_date_index.head()
# Out:
#             Bitcoin-BTC  Ethereum-ETH  Bitcoin-BSV  Litecoin-LTC  Monero-XMR  \
# Date
# 2020-12-31     29374.15        730.37       163.12        126.23      136.05
# 2020-12-30     29001.72        737.80       163.63        124.69      156.57
# 2020-12-29     28840.95        751.62       166.90        129.47      159.37
# 2020-12-28     27362.44        731.52       164.40        129.04      161.39
# 2020-12-27     27084.81        730.40       168.49        130.05      166.49
#
#             Dash-DASH  Kusama-KSM  Zcash-ZEC  Bitcoin Cash-BCH  Counos-CCXX
# Date
# 2020-12-31      88.24       71.96      63.99            343.05        89.10
# 2020-12-30      99.61       62.04      64.20            358.81        87.88
# 2020-12-29     101.68       61.26      66.54            353.09        87.67
# 2020-12-28     104.04       58.24      69.02            362.09        87.39
# 2020-12-27     107.27       50.32      67.65            338.18        87.18

# %%
# Group by year
all_date_index_grp = all_date_index.groupby([all_date_index.index.year]).mean()
all_date_index_grp
# Out:
#        Bitcoin-BTC  Ethereum-ETH  Bitcoin-BSV  Litecoin-LTC  Monero-XMR  \
# Date
# 2013    260.043710      0.000000     0.000000      6.748347    0.000000
# 2014    525.984082      0.000000     0.000000      9.784986    0.951736
# 2015    272.782384      0.374712     0.000000      2.696932    0.490705
# 2016    570.033197      9.797840     0.000000      3.791475    3.725023
# 2017   4040.715452    226.009726     0.000000     50.646986   76.847452
# 2018   7545.412082    481.776767    13.727890    105.236411  167.192466
# 2019   7404.442932    181.742795   109.121589     69.694438   66.484110
# 2020  11176.962514    309.181066   193.752432     56.473689   85.190191
#
#        Dash-DASH  Kusama-KSM   Zcash-ZEC  Bitcoin Cash-BCH  Counos-CCXX
# Date
# 2013    0.000000    0.000000    0.000000          0.000000     0.000000
# 2014    3.241430    0.000000    0.000000          0.000000     0.000000
# 2015    2.762110    0.000000    0.000000          0.000000     0.000000
# ...

# %%
# Plot closing prices
all_date_index_grp.hvplot(title="CoinMarketCap: Crypto Closing Prices", ylabel="Closing Price", xlabel="Year", kind='line', width=1000, height=500, x="Date")
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %% [raw]
# Conclusion: Bitcoin is king and the rest are peasants.

# %%
# Bar plot showing the total closing cost per day
all_date_index_grp.hvplot.bar(x='Date', y=["Bitcoin-BTC", "Ethereum-ETH", "Bitcoin-BSV", "Litecoin-LTC", "Monero-XMR", "Dash-DASH", "Kusama-KSM", "Zcash-ZEC", "Bitcoin Cash-BCH", "Counos-CCXX"],
                 stacked=True, rot=90, width=1000, height=450, ylabel="Closing Price", xlabel="Year", title="CoinMarketCap: Combined Closing Prices")
# Out:
# :Bars   [Date,Variable]   (value)

# %% [raw]
# Conclusion: The everage total closing prices for the 10 cryptocurrencies in 2020 is $12,300 vs $270 in 2013.

# %%
all_date_index_grp.describe()
# Out:
#         Bitcoin-BTC  Ethereum-ETH  Bitcoin-BSV  Litecoin-LTC  Monero-XMR  \
# count      8.000000      8.000000     8.000000      8.000000    8.000000
# mean    3974.547044    151.110363    39.575239     38.134158   50.110210
# std     4265.782920    180.963306    72.807363     38.201785   60.312418
# min      260.043710      0.000000     0.000000      2.696932    0.000000
# 25%      462.683658      0.281034     0.000000      6.009129    0.836478
# 50%     2305.374324     95.770317     0.000000     30.215986   35.104566
# 75%     7439.685219    246.802561    37.576315     59.778876   78.933137
# max    11176.962514    481.776767   193.752432    105.236411  167.192466
#
#         Dash-DASH  Kusama-KSM   Zcash-ZEC  Bitcoin Cash-BCH  Counos-CCXX
# count    8.000000    8.000000    8.000000          8.000000     8.000000
# mean    97.328244    2.179421   70.751555        223.945736     3.126858
# std    128.518070    6.134201   90.278465        303.514054     8.844090
# ...

# %%
# Calculate the correlation between cryptos
correlation = all_date_index.corr() 
correlation
# Out:
#                   Bitcoin-BTC  Ethereum-ETH  Bitcoin-BSV  Litecoin-LTC  \
# Bitcoin-BTC          1.000000      0.802847     0.663940      0.775288
# Ethereum-ETH         0.802847      1.000000     0.258014      0.905691
# Bitcoin-BSV          0.663940      0.258014     1.000000      0.270234
# Litecoin-LTC         0.775288      0.905691     0.270234      1.000000
# Monero-XMR           0.772932      0.953183     0.202595      0.950992
# Dash-DASH            0.557782      0.844846    -0.027747      0.881824
# Kusama-KSM           0.597435      0.341469     0.470149      0.147307
# Zcash-ZEC            0.462875      0.780229    -0.061558      0.743476
# Bitcoin Cash-BCH     0.624435      0.864329     0.064682      0.896077
# Counos-CCXX          0.614633      0.338130     0.467559      0.153564
#
#                   Monero-XMR  Dash-DASH  Kusama-KSM  Zcash-ZEC  \
# Bitcoin-BTC         0.772932   0.557782    0.597435   0.462875
# ...

# %%
# Plot correlation via Seaborn
plt.figure(figsize = (20,12))
intra_corr_plot = sns.heatmap(correlation, vmin=-1, vmax=1, annot=True, cmap="GnBu")
intra_corr_plot.figure.savefig("intra_corr_plot.png", bbox_inches="tight")

# %% [raw]
# Conclusion: Bitcoin and Ethereum are closely correlated (0.8) and Bitcoin SV and Zcash are least correlated at -0.062

# %%
# Calculate and plot rolling standard deviation: asses the risk over time
all_roll_std = all_date_index.rolling(window=30).std()
all_roll_std.plot(figsize=(20, 12), title="Crypto 30 Day Rolling Standard Deviation", fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Crypto 30 Day Rolling Standard Deviation'}, xlabel='Date'>

# %% [raw]
# Conclusion: Bitcoin is the most volatile among the 10 cryptos illustrated by the spikes above. Counos is the least risky shown flat-lining.

# %% [markdown]
# ## Panel Dashboard

# %%
# Generate the plots for each tab
trading_volume_plots = pn.Column("### Analysis: Volume of Trading Activity", "Coinbase provides historical data for 3 fiat currencies: the US Dollar (USD), the Euro (EUR), and the British Pound (GBP). The following visualizations compare the volumes of trading activity between those fiat currencies from 2012 to 2021.", trading_volume, unique_cryptocurrency_count, trading_volume_std)

# Generate the dashboard with tabs
dashboard = pn.Tabs(
    ('Volume of Trading Activity', trading_volume_plots)
)

# %%
dashboard.servable()
# Out:
# Tabs
#     [0] Column
#         [0] Markdown(str)
#         [1] Markdown(str)
#         [2] Column
#             [0] Column()
#             [1] Row
#                 [0] HoloViews(NdOverlay, name='interactive03137')
#         [3] Column
#             [0] Column()
#             [1] Row
#                 [0] HoloViews(NdOverlay, name='interactive03272')
#         [4] Column
#             [0] Column()
#             [1] Row
#                 [0] Plotly(Figure, name='interactive03407')
